# %%
import pickle
import matplotlib.pyplot as plt
import os

# %%
list_path = os.getcwd() + '/loss_list'

with open(list_path+'/regular_ce_list', 'rb') as file:
    regular_ce_list_eat = pickle.load(file)

with open(list_path+'/regular_kl_list', 'rb') as file:
    regular_kl_list_eat = pickle.load(file)
    
# with open(list_path+'/regular_ce_list_pure', 'rb') as file:
#     regular_ce_list_pure = pickle.load(file)

# with open(list_path+'/regular_kl_list_pure', 'rb') as file:
#     regular_kl_list_pure = pickle.load(file)
    
subtr_list = [a - b for a, b in zip(regular_kl_list_eat, regular_kl_list_eat)]

import matplotlib.pyplot as plt

# 두 개의 리스트
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# 그래프 그리기
plt.figure(figsize=(10, 5))  # 그래프의 크기 설정
plt.plot(regular_kl_list_eat, linestyle='-', color='b', label='KL Divergence Loss')  # 선 그래프

# 그래프 제목과 축 레이블 설정
plt.title('KL Divergence Loss Graph')
plt.xlabel('Iterations')
plt.ylabel('KL Divergence Loss')

# 범례 추가
plt.legend()

# 격자 추가
plt.grid(True)

# 그래프 표시
plt.show()
